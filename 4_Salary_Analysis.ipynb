# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import ast
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
def clean_job_skills(val):
    if pd.notna(val):
        return ast.literal_eval(val)

df['job_skills'] = df['job_skills'].apply(clean_job_skills)

# %%
job = 'Data Analyst'
country = 'United States'
top = 10

# %%
df_filtered = df[(df['job_country'] == country)].copy()
df_filtered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_exploded = df_filtered.explode('job_skills').copy()

# %%
df_filtered.dropna(subset='salary_year_avg', inplace= True)

# %%
df_filtered
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_titles = df['job_title_short'].value_counts().head(6).index.to_list()

# %%
df_plt = df_filtered[df_filtered['job_title_short'].isin(job_titles)]

# %%
df_plt
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
sns.boxplot(
    data= df_plt,
    x= 'salary_year_avg',
    y= 'job_title_short',
)
axs = plt.gca()
sns.despine()
plt.ylabel("")
sns.set_theme(style="ticks")
plt.xlabel("Yearly Salary On Average")
plt.title(f"High Paying Jobs(Data Related) in {country}")
plt.tight_layout()
axs.xaxis.set_major_formatter(lambda x, _ : f'${x / 1000}k')
plt.xlim(0, 600000)
plt.show()

# %%
df_filtered = df_exploded[(df_exploded['job_title_short'] == job) & (df_exploded['job_country'] == country)].copy()

# %%
df_filtered
# Out:
#        job_title_short                                    job_title  \
# 36        Data Analyst                                 Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# ...                ...                                          ...
# 785685    Data Analyst                                 Data Analyst
# 785703    Data Analyst      Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
#
#             job_location           job_via job_schedule_type  \
# 36        Des Moines, IA   via Trabajo.org         Full-time
# ...

# %%
df_plt_count = df_filtered.groupby(by= 'job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by= 'count', ascending= False).head(top).sort_values(by= 'median', ascending= False)
df_plt_median = df_filtered.groupby(by= 'job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by= 'median', ascending= False).head(top)

# %%
df_plt_count.reset_index(inplace= True)

# %%
df_plt_median.reset_index(inplace= True)

# %%
df_plt_count
# Out:
#    job_skills  count    median
# 0      python   1431  97500.00
# 1     tableau   1364  92875.00
# 2           r    893  92500.00
# 3  sql server    286  92500.00
# 4         sql   2508  91000.00
# 5         sas    926  90000.00
# 6    power bi    838  90000.00
# 7  powerpoint    462  85000.00
# 8       excel   1808  84392.00
# 9        word    461  81194.75

# %%
fig, axs = plt.subplots(2, 1, figsize=(10,8))
sns.barplot(
    data= df_plt_median,
      x= 'median', 
      y = 'job_skills', 
      ax=axs[0],
      hue= 'job_skills',
      palette= 'light:b_r'
)
sns.barplot(
    data= df_plt_count, 
    x= 'median', 
    y = 'job_skills', 
    hue= 'job_skills',
    palette= 'light:b_r',
    ax=axs[1]
)
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_ : f'${x/1000}k'))
axs[0].set_xlabel('Avg. Yearly Salary')
axs[0].set_ylabel('')
axs[0].set_title('Top 10 In-Demand  Skills', fontsize= 14)

axs[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_ : f'${x/1000}k'))
axs[1].set_xlabel('Job Title Short')
axs[1].set_ylabel('')
axs[1].set_title('Top 10 High Paying Skills', fontsize= 14)
axs[1].set_xlim(0, 200000)

plt.setp(axs[1].get_xticklabels(),rotation = 45, ha='right')
plt.setp(axs[0].get_xticklabels(),rotation = 45, ha='right')

plt.tight_layout()
fig.subplots_adjust(top=0.90)
fig.set_size_inches(10, 8)
fig.suptitle('High Paying v/s In-Demand', fontsize=15, x = 0.55)
plt.show()
